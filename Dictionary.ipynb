# %%
#Dictionary
# -indexing
# -ordered
# -multiple and duplicate data
# -mutable

# %%
# d={}
# d={<key>:<value>,<key>:<value>, ...}

# %%
d={'a':'Apple','b':"Ball","c":"Cat"}
print(d)
print(type(d))
# Out:
# {'a': 'Apple', 'b': 'Ball', 'c': 'Cat'}
# <class 'dict'>

# %%
# d={}
# d=dict()

# %%
d={'a':'Apple','b':"Ball","c":"Cat"}
print(d['a'])
print(d['b'])
print(d['c'])
# Out:
# Apple
# Ball
# Cat

# %%
d={'a':'Apple','b':"Ball","c":"Cat",'A':'antt'}
print(d['a'])
d
# Out:
# Apple
# {'a': 'Apple', 'b': 'Ball', 'c': 'Cat', 'A': 'antt'}

# %%
#CRUD

# %%
#Create
d=dict()
d['a']='Apple'
d['b']='Ball'
d['c']="Cat"
print(d)
# Out:
# {'a': 'Apple', 'b': 'Ball', 'c': 'Cat'}

# %%
# in dict there is no + and *

# %%
a={1:1,2:4,3:9,4:16,5:25,}
b={6:36,7:49,8:64}
a.update(b)
print(a)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
d={}
n=int(input("Enter n="))
for i in range(n):
    name=input("Enter name=")
    phone=input("Enter phone=")
    d[name]=phone
print(d)
# Out:
# Enter n= 2
# Enter name= Ram
# Enter phone= 989898989
# Enter name= Sami
# Enter phone= 09090909
# {'Ram': '989898989', 'Sami': '09090909'}

# %%
#Read
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
print(a)
print(a.values())
print(a.keys())
print(a.items())
# Out:
# {'Ram': '98989898', 'Shyam': '0099090', 'sami': '83898393'}
# None
# dict_values(['98989898', '0099090', '83898393'])
# dict_keys(['Ram', 'Shyam', 'sami'])
# dict_items([('Ram', '98989898'), ('Shyam', '0099090'), ('sami', '83898393')])

# %%
a=dict(a='apple',b='Ball')
print(a)
a.update({'c':'call'})
print(a)
# Out:
# {'a': 'apple', 'b': 'Ball'}
# {'a': 'apple', 'b': 'Ball', 'c': 'call'}

# %%
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
# print(a)
# print(a.values())
# print(a.keys())
# print(a.items())
for i in range(len(a)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
# print(a)
# print(a.values())
# print(a.keys())
# print(a.items())
for i in a:
    print(i)
# Out:
# Ram
# Shyam
# sami

# %%
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
for value in a.values():
    print(value)
# Out:
# 98989898
# 0099090
# 83898393

# %%
for i in a.items():
    print(i)
# Out:
# ('Ram', '98989898')
# ('Shyam', '0099090')
# ('sami', '83898393')

# %%
#update
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
a['Ram']='0000000'
a
a.update({'Sami':'000909'})
a
# Out:
# {'Ram': '0000000', 'Shyam': '0099090', 'sami': '83898393', 'Sami': '000909'}

# %%
#Delete
#del ,#pop()

# %%
# Deleting
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
del a['Ram']
a
# Out:
# {'Shyam': '0099090', 'sami': '83898393'}

# %%
# # Deleting
# a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
# b= del a['Ram']
# a
# b-----------not correct way

# %%
# Deleting
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
b=a.pop('Ram')
print(a)
print(b)
# Out:
# {'Shyam': '0099090', 'sami': '83898393'}
# 98989898

# %%
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
a.clear()
a
# Out:
# {}

# %%
a={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
key, value=a.popitem()
print(key,value)
# Out:
# sami 83898393

# %%
# adding
d={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
d["Sa"]='09'
d
# Out:
# {'Ram': '98989898', 'Shyam': '0099090', 'sami': '83898393', 'Sa': '09'}

# %%
d={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
print(d)
print(d.get('S'))
# Out:
# {'Ram': '98989898', 'Shyam': '0099090', 'sami': '83898393'}
# None

# %%
# d={'Ram':'98989898','Shyam':'0099090','sami':"83898393"}
# print(d)
# print(d['s'])------------not correct way

# %%
# list inside dictonary
d={'Ram':[90909090909,9090989898],
  'Shyam':[909009090,3003903039],
  'Hari':[9900009,38874774848]}
d
# Out:
# {'Ram': [90909090909, 9090989898],
#  'Shyam': [909009090, 3003903039],
#  'Hari': [9900009, 38874774848]}

# %%
d={}
n=int(input("Enter n="))
for i in range (n):
    name=input("Enter name=")
    ntc=input("Enter ntc number=")
    ncell=input("Enter Ncell number=")
    d[name]=[ntc,ncell]
print(d)
# Out:
# Enter n= 2
# Enter name= Samira
# Enter ntc number= 9823564312
# Enter Ncell number= 9861287025
# Enter name= Raj
# Enter ntc number= 9898989
# Enter Ncell number= 1828813712
# {'Samira': ['9823564312', '9861287025'], 'Raj': ['9898989', '1828813712']}

# %%
print(d['Samira'][1])
print(d['Samira'][0])
# Out:
# 9861287025
# 9823564312

# %%
d['Samira'][1]='99892899382'
print(d)
# Out:
# {'Samira': ['9823564312', '99892899382'], 'Raj': ['9898989', '1828813712']}

# %%
d={'name':['Ram','Shyam','Hari'],
  'ntc':['98899999','989876','897788797'],
  'ncell':['90909090','90989899','898779999']}

d
# Out:
# {'name': ['Ram', 'Shyam', 'Hari'],
#  'ntc': ['98899999', '989876', '897788797'],
#  'ncell': ['90909090', '90989899', '898779999']}

# %%
d={'name':[],
  'ntc':[],
  'ncell':[]}

n=int(input("Enter n="))
for i in range (n):
    name=input("Enter name=")
    ntc=int(input("Enter ntc number="))
    ncell=int(input("Enter ncell number"))
    d['name'].append(name)
    d['ntc'].append(ntc)
    d['ncell'].append(ncell)
print(d)
# Out:
# Enter n= 2
# Enter name= Sami
# Enter ntc number= 328392
# Enter ncell number 2398879
# Enter name= Shrey
# Enter ntc number= 1290
# Enter ncell number 12309128
# {'name': ['Sami', 'Shrey'], 'ntc': [328392, 1290], 'ncell': [2398879, 12309128]}

# %%
print(d['name'][0],d['ntc'][0],d['ncell'][0])
# Out:
# Sami 328392 2398879

# %%
d["name"].index('Sami')
# Out:
# 0

# %%
d['name'][0]="Samira"
d
# Out:
# {'name': ['Samira', 'Shrey'],
#  'ntc': [328392, 1290],
#  'ncell': [2398879, 12309128]}

# %%
#dict inside list
l=[{'name':'Ram','ntc':'9898989','ncell':'812713'},
   {'name':'Shyam','ntc':'9777798989','ncell':'99999812713'},
  {'name':'Hari','ntc':'989sawe438989','ncell':'812asdsad713'}]
l
print(type(l))
# Out:
# <class 'list'>

# %%
l=[]
n=int(input("Enter n="))
for i in range (n):
    name=input("Enter name=")
    ntc=int(input("Enter ntc number="))
    ncell=int(input("Enter ncell number"))
    x={'name':name,'ntc':ntc,'ncell':ncell}
    l.append(x)
print(l)
# Out:
# Enter n= 2
# Enter name= rr
# Enter ntc number= 2342
# Enter ncell number 2342
# Enter name= ff
# Enter ntc number= 23423
# Enter ncell number 234
# [{'name': 'rr', 'ntc': 2342, 'ncell': 2342}, {'name': 'ff', 'ntc': 23423, 'ncell': 234}]

# %%
l[0]['name']
# Out:
# 'rr'

# %%
#dict inside dict
d={1:{'name': 'rr', 'ntc': 2342, 'ncell': 2342}, 
   2:{'name': 'ff', 'ntc': 23423, 'ncell': 234}}
d
# Out:
# {1: {'name': 'rr', 'ntc': 2342, 'ncell': 2342},
#  2: {'name': 'ff', 'ntc': 23423, 'ncell': 234}}

# %%
# create dict inside dict
# do CURD operation in
# -dict inside list
# -list inside dict
# -dict inside dict

# %%
info={
    "key":"value",
    'Name':'Samira',
    'learning':'Coding',
    'age':35,
    'is_adult':True,
    "marks":99.9
    
}
print(info)
# Out:
# {'key': 'value', 'Name': 'Samira', 'learning': 'Coding', 'age': 35, 'is_adult': True, 'marks': 99.9}

# %%
info={
    'name':'ApnaCollege',
    'subject':['python','c','java'],
    'topics':("dict","Set"),
    'age':35,
    'is_adult':True,
    "marks":99.9, 
    12:90,
    12.2:22,
    True:33
}
print(info)
print(type(info))
print(info['name'])
print(info['is_adult'])
print(info['name'])
# Out:
# {'name': 'ApnaCollege', 'subject': ['python', 'c', 'java'], 'topics': ('dict', 'Set'), 'age': 35, 'is_adult': True, 'marks': 99.9, 12: 90, 12.2: 22, True: 33}
# <class 'dict'>
# ApnaCollege
# True
# ApnaCollege

# %%
null_dict={}
null_dict['name']='Sami'
print(null_dict)
info['name']='Samira'
info['surname']="ulak"
print(info)
# Out:
# {'name': 'Sami'}
# {'name': 'Samira', 'subject': ['python', 'c', 'java'], 'topics': ('dict', 'Set'), 'age': 35, 'is_adult': True, 'marks': 99.9, 12: 90, 12.2: 22, True: 33, 'surname': 'ulak'}

# %%
student={
    'name':'Samira',
    'subject':{
        'physic':97,
        'chem':98,
        'math':90
    }
}
print(student)

#nested dictionary
print(student['subject']['chem'])
# Out:
# {'name': 'Samira', 'subject': {'physic': 97, 'chem': 98, 'math': 90}}
# 98

# %%
#printing all keys-----don't return nested keys
print(student.keys())
# Out:
# dict_keys(['name', 'subject'])

# %%
#printing in a normal list
print(list(student.keys()))
# Out:
# ['name', 'subject']

# %%
#total no of keys
print(len(student))
print(len(list(student.keys())))
# Out:
# 2
# 2

# %%
#printing all values
print(student.values())
# Out:
# dict_values(['Samira', {'physic': 97, 'chem': 98, 'math': 90}])

# %%
#printing in a normal list
print(list(student.values()))
# Out:
# ['Samira', {'physic': 97, 'chem': 98, 'math': 90}]

# %%
#printing all items(key and value)
print(student.items())
# Out:
# dict_items([('name', 'Samira'), ('subject', {'physic': 97, 'chem': 98, 'math': 90})])

# %%
#printing all items in list(typecaste)(key and value)
print(list(student.items()))
# Out:
# [('name', 'Samira'), ('subject', {'physic': 97, 'chem': 98, 'math': 90})]

# %%
pairs=list(student.items())
print(pairs[0])
print(pairs[1])
# Out:
# ('name', 'Samira')
# ('subject', {'physic': 97, 'chem': 98, 'math': 90})

# %%
#.get("")
print(student['name'])#---error
print(student.get('name2'))#---none
# Out:
# Samira
# None

# %%
#.update()
student.update({'city':'BKT'})
print(student)
# Out:
# {'name': 'Samira', 'subject': {'physic': 97, 'chem': 98, 'math': 90}, 'city': 'BKT'}

# %%
new_dict={'add':'BKT','age':23}
student.update(new_dict)
print(student)
# Out:
# {'name': 'Samira', 'subject': {'physic': 97, 'chem': 98, 'math': 90}, 'city': 'BKT', 'add': 'BKT', 'age': 23}
