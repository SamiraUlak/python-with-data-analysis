# %%
a=10
print(a)

# %%
a=10
b=10.5
c='Hello World'
d=True
print(a)
print(b)
print(c)
print(d)
print(a,b,c,d)
# Out:
# 10
# 10.5
# Hello World
# True
# 10 10.5 Hello World True

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
print(a//b)
print(a%b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1000
# 3
# 1

# %%
#string
a='Hello '
b='World'
c=a+b
print(c)
# Out:
# Hello World

# %%
a='Hello World '
c=a*2
print(c)
# Out:
# Hello World Hello World

# %%
a ='shreyna '
b='ulu'
print(a+b)
# Out:
# shreyna ulu

# %%
a=10.5
b=int(a)
print(b)
# Out:
# 10

# %%
a=input("Enter a = ")
print(a)
print(type(a))
# Out:
# Enter a =  10.8
# 10.8
# <class 'str'>

# %%
a =int(input("Enter a= "))
b=int(input("Enter b="))
c=a+b
print(c)
# Out:
# Enter a=  1
# Enter b= 2
# 3

# %%
p = int(input("Enter p= "))
t = float(input("Enter t= "))
r = float(input("Enter r= "))

i=(p*t*r)/100
print("The value of interest is ", i)
# Out:
# Enter p=  100
# Enter t=  2.5
# Enter r=  20
# The value of interest is  50.0

# %%
a=10
print(a)

# %%
a=10
b=float(a)
print(a)
# Out:
# 10

# %%
a=int(input("Enter value of a=\n"))
b=float(input("Enter value of b=\n"))
print((a))
print((b))
# Out:
# Enter value of a=
#  10
# Enter value of b=
#  8
# 10
# 8.0

# %%
p=int(input("Enter value of p="))
t=float(input("Enter value of t="))
r=float(input("Enter value of r="))
i=(p*t*r)/100
print("The value of i is " ,i)
# Out:
# Enter value of p= 10
# Enter value of t= 2.4
# Enter value of r= 2.4
# The value of i is  0.576

# %%
physic=int(input("Enter value of physic="))
chemistry=int(input("Enter value of chem="))
math=int(input("Enter value of math="))
total=physic+chemistry+math
avg=int(total/3)
print("The average is ",avg)
print("the marks is ",total)
# Out:
# Enter value of physic= 20
# Enter value of chem= 20
# Enter value of math= 20
# The average is  20
# the marks is  60

# %%
name=input("Enter name")
age=int(input("Enter age"))
a=str(age)
add=str(input("Enter address"))

print("Hello! My name is", name + " I am", a + " I live in",add )
# Out:
# Enter name Sami
# Enter age 23
# Enter address BKT
# Hello! My name is Sami I am 23 I live in BKT

# %%
info="Hello! My name is" + name + " I am" +a + " I live in"+ add 
print(info)
# Out:
# Hello! My name issami I am23 I live inbkt
